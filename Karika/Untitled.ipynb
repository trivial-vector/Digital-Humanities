# %%
import pandas as pd
import pymongo

# %%
filename = "./Resources/Reservation Census charting_1910.csv"
df_basic_data_allyrs = pd.read_csv(filename)

# %%
df_basic_data_allyrs
# Out:
#      Line #  House No    Street Name   LastName  GivenName Relation (4)  \
# 0         1     841.0  Arthur Street       Koch       Katy         Head
# 1         2     841.0  Arthur Street       Rehr   Margaret      Boarder
# 2         3     841.0  Arthur Street     Parker      Hazel          NaN
# 3         4     837.0  Arthur Street      Garza       Rosa         Head
# 4         5     837.0  Arthur Street     Delgar  Francisco      Boarder
# 5         6     837.0  Arthur Street     Concha      Sarga      Boarder
# 6         7     837.0  Arthur Street      Duque      Sarah      Boarder
# 7         8     907.0  Hobson Street      Wise      Jennie         Head
# 8         9     912.0  Hobson Street     Howard        Ada         Head
# 9        10     912.0  Hobson Street      Janis      Eauma      Boarder
# 10       11     830.0  Arthur Street      King       Josie         Head
# 11       12     830.0  Arthur Street     Nelson     Eunise      Boarder
# ...

# %%
df_basic_data_allyrs["Age at last birthday (8)"] = df_basic_data_allyrs["Age at last birthday (8)"].replace(["months"],"B")

# %%
df_basic_data_allyrs["Age at last birthday (8)"].unique()
# Out:
# array(['27', '23', '15', '28', '25', '20', '33', '22', '21', '26', '35',
#        '30', '18', '1', '32', '24', '42', '34', '65', '43', '31', '12',
#        '38', '36', '16', '19', '13', '10', '2', '58', '41', '40', '60',
#        '52', '17', '?', '4', '29', '7 months', '39', '5', '47', '3', '50',
#        '69', '55', '8', '57', '64', '56', '45', '11', '7', '70', '49',
#        '5 months', '6', '54', '44', '62', '14', '3 months', '37', nan],
#       dtype=object)
